# %%
pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (1.35.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: colorama in c:\users\ziad\anaconda3\envs\electro\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from openai import OpenAI

client = OpenAI(
    api_key = os.getenv("OPENAI_API_KEY"),
)

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [
              {"role": "user",
              "content": prompt}
               ]
    Response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # model output randomness
    )
    return Response.choices[0].message.content

# %%
text = f"""
سيكون من الأفضل أن تعبر عن ما تريد أن يفعله النموذج من خلال \
تقديم تعليمات واضحة و\
محددة كما يمكنك جعلها. \
سيؤدي هذا إلى توجيه النموذج نحو المخرجات المطلوبة \
وتقليل فرص الحصول على غير ذات صلة أدناه\
أو ردود غير صحيحة تأكد من التمييز بين كتابة \
مطالبة واضحة من كتابة مطالبة قصيرة. \
في العديد من الحالات، توفر المطالبات الأطول مزيدًا من الوضوح \
وسياق النموذج، مما قد يؤدي إلى \
مخرجات أكثر تفصيلاً وذات صلة.\
"""

# %%
prompt = f"""
لخص النص المحدد بعلامات خلفية ثلاثية \
في جملة واحدة.
{text}
"""

# %%
response = get_completion(prompt)
print(response)
# Out:
# توجيه النموذج نحو المخرجات المطلوبة يتطلب تقديم تعليمات واضحة ومحددة، مما يساعد في تجنب الردود غير صحيحة وتحقيق نتائج دقيقة وملائمة.

# %%
prompt = f"""
لخص النص المحدد بعلامات خلفية ثلاثية \
في جملة واحدة.
```{text}```
"""

# %%
response = get_completion(prompt)
print(response)
# Out:
# توجيه النموذج نحو المخرجات المطلوبة وتقليل فرص الحصول على غير ذات صلة من خلال تقديم تعليمات واضحة ومحددة.

# %%
prompt = f"""
قم بإنشاء قائمة بثلاثة عناوين كتب مكونة من \
مع مؤلفيها وأنواعها.

قم بتزويدها بتنسيق JSON بالمفاتيح التالية:
book_id, title, author, genre.
"""
response = get_completion(prompt)
print(response)
# Out:
# [
#     {
#         "book_id": 1,
#         "title": "1984",
#         "author": "George Orwell",
#         "genre": "Dystopian Fiction"
#     },
#     {
#         "book_id": 2,
#         "title": "To Kill a Mockingbird",
#         "author": "Harper Lee",
#         "genre": "Classic Literature"
#     },
#     {
#         "book_id": 3,
#         "title": "The Great Gatsby",
#         "author": "F. Scott Fitzgerald",
#         "genre": "Historical Fiction"
#     }
# ]

# %%
import json

# JSON string
response = """ {"books":
[
    {
        "book_id": 1,
        "title": "1984",
        "author": "George Orwell",
        "genre": "Dystopian Fiction"
    },
    {
        "book_id": 2,
        "title": "To Kill a Mockingbird",
        "author": "Harper Lee",
        "genre": "Classic Literature"
    },
    {
        "book_id": 3,
        "title": "The Great Gatsby",
        "author": "F. Scott Fitzgerald",
        "genre": "Historical Fiction"
    }
]}
"""

# Convert string to Python dict
response_dict = json.loads(response)
print("\n",response_dict['books'][1]["title"])
# Out:
#  To Kill a Mockingbird

# %%
prompt = f"أنشئ قائمة بثلاثة عناوين كتب مختلقة مع مؤلفيها وأنواعها."

response = get_completion(prompt)
print(response)
# Out:
# 1. "المدينة المفقودة" لـ سارة جونز - رواية خيالية
# 2. "سر القلادة الزرقاء" لـ محمد علي - رواية غموض
# 3. "حكايات من عوالم مختلفة" لـ ليلى عبد الرحمن - مجموعة قصص قصيرة

# %%
prompt = f"""
مهمتك هي الإجابة بأسلوب متسق.

الطفل: علمني عن الصبر.

الجد: النهر الذي ينحت أعمق وادٍ يتدفق من نبع متواضع؛\
 أعظم سيمفونية تبدأ بنغمة واحدة؛\
 أكثر الأقمشة تعقيدًا تبدأ بخيط واحد\.

الطفل: علمني عن الصمود.
"""
response = get_completion(prompt)
print(response)
# Out:
# الجد: الصمود هو قوة الروح التي تسمح للإنسان بالثبات والصمود في وجه التحديات والصعاب، كما أنه القدرة على الاستمرار وعدم الاستسلام أمام الصعوبات والمصاعب. الصمود يعني الثبات على المبادئ والقيم وعدم الانكسار أمام الضغوطات والمشاكل.
