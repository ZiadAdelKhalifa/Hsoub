# %%
import requests
headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'}
respons=requests.get('https://www.amazon.ae/s',headers=headers,params={'k':'ساعة+يد'})


print(respons.text)#output will be the HTML page
#print(respons.status_code)#200 means request is done
# Out:
# <!doctype html><html lang="en-ae" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
#
# <script type='text/javascript'>var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta http-equiv='x-dns-prefetch-control' content='on'>
# <link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">
# <link rel="dns-prefetch" href="https://m.media-amazon.com">
# <link rel="dns-prefetch" href="https://completion.amazon.com">
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type='text/javascript'>
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
from bs4 import BeautifulSoup
import requests

url='https://www.amazon.ae/Seiko-Automatic-Display-Stainless-Snkp21J1/dp/B07NQLSVXF/ref=sr_1_1_sspa?crid=22XTOK7JZL1DK&dib=eyJ2IjoiMSJ9.YIRNEnoZvuqk6UpZ67hKvX-r3utHTcdTY0z1eQJA737_yI_Sb9CkDDKDbYBfm7WEVJPfYAeJD5iw7VvvvftCrTDXNftgzfMqY_--ZH_uz0O3l4wTJbax6QogUH7c5INIGlAufDBRFJMRa9GU1n8mAxL8riqB-2LJbJdRKeBhdVXPiDaQ-edsZd6uYkvUFwvmAsPrr7jJ3bdfNvrp-hpz5XDHLUGctB2F5R44ssnD0ZJLmowNduEukgZii7EelpJ3YXHhNtwUOapAzBolB4s077jc3FUBa0CP0aOQTzMEqPU.NVQiIBKC27K-v5tDgLP6SvG5CsCpY8F_XOThdKSw3wQ&dib_tag=se&keywords=%D8%B3%D8%A7%D8%B9%D8%A9+%D9%8A%D8%AF&qid=1718908553&sprefix=%D8%B3%D8%A7%D8%B9%D8%A9+%D9%8A%D8%AF%2Caps%2C392&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1'

headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'}
respons=requests.get(url,headers=headers,params={'k':'ساعة+يد'})

soup=BeautifulSoup(respons.content,'html.parser')

#print(soup.prettify())

title=soup.find('span',id='productTitle')

print(title.string.strip())
# Out:
# Seiko Men's Automatic Watch With Analog Display And Stainless Steel Strap Snkp21J1

# %%
from bs4 import BeautifulSoup
import requests

url='https://www.amazon.ae/Seiko-Automatic-Display-Stainless-Snkp21J1/dp/B07NQLSVXF/ref=sr_1_1_sspa?crid=22XTOK7JZL1DK&dib=eyJ2IjoiMSJ9.YIRNEnoZvuqk6UpZ67hKvX-r3utHTcdTY0z1eQJA737_yI_Sb9CkDDKDbYBfm7WEVJPfYAeJD5iw7VvvvftCrTDXNftgzfMqY_--ZH_uz0O3l4wTJbax6QogUH7c5INIGlAufDBRFJMRa9GU1n8mAxL8riqB-2LJbJdRKeBhdVXPiDaQ-edsZd6uYkvUFwvmAsPrr7jJ3bdfNvrp-hpz5XDHLUGctB2F5R44ssnD0ZJLmowNduEukgZii7EelpJ3YXHhNtwUOapAzBolB4s077jc3FUBa0CP0aOQTzMEqPU.NVQiIBKC27K-v5tDgLP6SvG5CsCpY8F_XOThdKSw3wQ&dib_tag=se&keywords=%D8%B3%D8%A7%D8%B9%D8%A9+%D9%8A%D8%AF&qid=1718908553&sprefix=%D8%B3%D8%A7%D8%B9%D8%A9+%D9%8A%D8%AF%2Caps%2C392&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1'

headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'}
respons=requests.get(url,headers=headers,params={'k':'ساعة+يد'})

soup=BeautifulSoup(respons.content,'html.parser')

#print(soup.prettify())



whole_price=soup.find('span',class_='a-price')

print(whole_price.get_text().strip())
# Out:
# AED548.98

# %%
url='https://www.amazon.ae/Seiko-Automatic-Display-Stainless-Snkp21J1/dp/B07NQLSVXF/ref=sr_1_1_sspa?crid=22XTOK7JZL1DK&dib=eyJ2IjoiMSJ9.YIRNEnoZvuqk6UpZ67hKvX-r3utHTcdTY0z1eQJA737_yI_Sb9CkDDKDbYBfm7WEVJPfYAeJD5iw7VvvvftCrTDXNftgzfMqY_--ZH_uz0O3l4wTJbax6QogUH7c5INIGlAufDBRFJMRa9GU1n8mAxL8riqB-2LJbJdRKeBhdVXPiDaQ-edsZd6uYkvUFwvmAsPrr7jJ3bdfNvrp-hpz5XDHLUGctB2F5R44ssnD0ZJLmowNduEukgZii7EelpJ3YXHhNtwUOapAzBolB4s077jc3FUBa0CP0aOQTzMEqPU.NVQiIBKC27K-v5tDgLP6SvG5CsCpY8F_XOThdKSw3wQ&dib_tag=se&keywords=%D8%B3%D8%A7%D8%B9%D8%A9+%D9%8A%D8%AF&qid=1718908553&sprefix=%D8%B3%D8%A7%D8%B9%D8%A9+%D9%8A%D8%AF%2Caps%2C392&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1'

headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'}
respons=requests.get(url,headers=headers,params={'k':'ساعة+يد'})

soup=BeautifulSoup(respons.content,'html.parser')

#print(soup.prettify())



picture=soup.find('img',class_='a-dynamic-image')

print(picture['src'])
# Out:
# https://m.media-amazon.com/images/I/71o856AV7EL.__AC_SX300_SY300_QL70_ML2_.jpg

# %%
url='https://www.amazon.ae/Seiko-Automatic-Display-Stainless-Snkp21J1/dp/B07NQLSVXF/ref=sr_1_1_sspa?crid=22XTOK7JZL1DK&dib=eyJ2IjoiMSJ9.YIRNEnoZvuqk6UpZ67hKvX-r3utHTcdTY0z1eQJA737_yI_Sb9CkDDKDbYBfm7WEVJPfYAeJD5iw7VvvvftCrTDXNftgzfMqY_--ZH_uz0O3l4wTJbax6QogUH7c5INIGlAufDBRFJMRa9GU1n8mAxL8riqB-2LJbJdRKeBhdVXPiDaQ-edsZd6uYkvUFwvmAsPrr7jJ3bdfNvrp-hpz5XDHLUGctB2F5R44ssnD0ZJLmowNduEukgZii7EelpJ3YXHhNtwUOapAzBolB4s077jc3FUBa0CP0aOQTzMEqPU.NVQiIBKC27K-v5tDgLP6SvG5CsCpY8F_XOThdKSw3wQ&dib_tag=se&keywords=%D8%B3%D8%A7%D8%B9%D8%A9+%D9%8A%D8%AF&qid=1718908553&sprefix=%D8%B3%D8%A7%D8%B9%D8%A9+%D9%8A%D8%AF%2Caps%2C392&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1'

headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'}
respons=requests.get(url,headers=headers,params={'k':'ساعة+يد'})

soup=BeautifulSoup(respons.content,'html.parser')

#print(soup.prettify())

tech_details={}

table=soup.find('table',class_="a-keyvalue a-spacing-mini")
print(table)
rows=table.find_all('tr')


for row in rows:
    key=row.th.string.strip()
    value=row.td.string.strip()
    tech_details[key]=value




print(tech_details)
# Out:
# <table class="a-keyvalue a-spacing-mini" id="technicalSpecifications_section_1"> <tr> <th class="a-span5 a-size-base"> Brand, Seller, or Collection Name </th> <td class="a-span7 a-size-base"> Seiko </td> </tr> <tr> <th class="a-span5 a-size-base"> Model number </th> <td class="a-span7 a-size-base"> SNKP21J1 </td> </tr> <tr> <th class="a-span5 a-size-base"> Part Number </th> <td class="a-span7 a-size-base"> SNKP21J1 </td> </tr> <tr> <th class="a-span5 a-size-base"> Item Shape </th> <td class="a-span7 a-size-base"> Round </td> </tr> <tr> <th class="a-span5 a-size-base"> Dial window material type </th> <td class="a-span7 a-size-base"> Mineral </td> </tr> <tr> <th class="a-span5 a-size-base"> Display Type </th> <td class="a-span7 a-size-base"> Analog </td> </tr> <tr> <th class="a-span5 a-size-base"> Clasp </th> <td class="a-span7 a-size-base"> Deployment Clasp </td> </tr> <tr> <th class="a-span5 a-size-base"> Case material </th> <td class="a-span7 a-size-base"> Stainless Steel </td> </tr
# ...
