# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("dataset.csv")

df = df[['Date' ,'Time' ,'Latitude' ,'Longitude' ,'Depth' ,'Magnitude']]
df
# Out:
#              Date      Time  Latitude  Longitude   Depth  Magnitude
# 0      01/02/1965  13:44:18   19.2460   145.6160  131.60        6.0
# 1      01/04/1965  11:29:49    1.8630   127.3520   80.00        5.8
# 2      01/05/1965  18:05:58  -20.5790  -173.9720   20.00        6.2
# 3      01/08/1965  18:49:43  -59.0760   -23.5570   15.00        5.8
# 4      01/09/1965  13:32:50   11.9380   126.4270   15.00        5.8
# ...           ...       ...       ...        ...     ...        ...
# 23407  12/28/2016   8:22:12   38.3917  -118.8941   12.30        5.6
# 23408  12/28/2016   9:13:47   38.3777  -118.8957    8.80        5.5
# 23409  12/28/2016  12:38:51   36.9179   140.4262   10.00        5.9
# 23410  12/29/2016  22:30:19   -9.0283   118.6639   79.00        6.3
# 23411  12/30/2016  20:08:28   37.3973   141.4103   11.94        5.5
#
# [23412 rows x 6 columns]

# %%
import datetime

current_datetime = datetime.datetime.now()
print("Now is : ", current_datetime)

#
timestamp = current_datetime.timestamp()

print("Time stamp (seconds): ", timestamp)
# Out:
# Now is :  2024-08-19 15:33:02.928346
# Time stamp (seconds):  1724070782.928346

# %%
import datetime

timestamps = []
for _, row in df.iterrows():
    try:
        d = row['Date']
        t = row['Time']
        
        full_date_string= d + " " + t
        
        full_date = datetime.datetime.strptime(full_date_string, '%m/%d/%Y %H:%M:%S')
        
        timestamp = full_date.timestamp()
        
        timestamps.append(timestamp)
        
    except Exception:
        timestamps.append('ValueError')

# %%
df['Timestamp'] = timestamps

df = df.drop(['Date', 'Time'], axis=1)

df = df[df.Timestamp != 'ValueError']

df['Timestamp'] = df['Timestamp'].astype(float)

df.head()
# Out:
#       Latitude  Longitude  Depth  Magnitude  Timestamp
# 1457    24.185    102.543   11.3        7.1   313241.0
# 1458    23.984    102.732   15.0        5.9   380950.0
# 1459    -9.583    151.493   15.0        6.3   444954.0
# 1460    15.785    -59.808   36.7        6.0   539774.0
# 1461   -34.850    178.782  199.4        6.8   659561.0

# %%
# !pip install basemap
# Out:
# Requirement already satisfied: basemap in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (1.4.1)
# Requirement already satisfied: basemap-data<1.4,>=1.3.2 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from basemap) (1.3.2)
# Requirement already satisfied: pyshp<2.4,>=1.2 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from basemap) (2.3.1)
# Requirement already satisfied: matplotlib<3.9,>=1.5 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from basemap) (3.5.3)
# Requirement already satisfied: pyproj<3.7.0,>=1.9.3 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from basemap) (3.5.0)
# Requirement already satisfied: packaging<24.0,>=16.0 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from basemap) (23.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from basemap) (1.24.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (10.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (2.9.0.post0)
# Requirement already satisfied: certifi in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from pyproj<3.7.0,>=1.9.3->basemap) (2024.7.4)
# Requirement already satisfied: six>=1.5 in c:\users\ziad\anaconda3\envs\id_card\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.9,>=1.5->basemap) (1.16.0)

# %%
from mpl_toolkits.basemap import Basemap

m = Basemap()

longitudes = df["Longitude"].tolist()

latitudes = df["Latitude"].tolist()

x,y = m(longitudes,latitudes)

fig = plt.figure(figsize=(12,10))

plt.title("All affected areas")

m.plot(x, y, "o", markersize = 2, color = 'blue')

#to draw the boundary of the beach
m.drawcoastlines()

m.fillcontinents(color='coral',lake_color='aqua')

m.drawmapboundary()

m.drawcountries()

plt.show()

# %%
X = df[['Latitude', 'Longitude', 'Timestamp']].values

y = df[['Depth', 'Magnitude']].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout

model = Sequential()
model.add(Input(shape=(3,)))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dense(2, activation='linear'))

# %%
model.compile(optimizer='adam', loss='mean_absolute_error')

# %%
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test,y_test))
# Out:
# Epoch 1/20
# 515/515 [==============================] - 4s 5ms/step - loss: 29.8002 - val_loss: 27.4558
# Epoch 2/20
# 515/515 [==============================] - 2s 3ms/step - loss: 27.1357 - val_loss: 27.2244
# Epoch 3/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.8866 - val_loss: 27.1237
# Epoch 4/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.7614 - val_loss: 27.0331
# Epoch 5/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.7022 - val_loss: 27.0015
# Epoch 6/20
# 515/515 [==============================] - 2s 5ms/step - loss: 26.6621 - val_loss: 26.9660
# Epoch 7/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.5826 - val_loss: 26.8926
# Epoch 8/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.5979 - val_loss: 26.8310
# Epoch 9/20
# 515/515 [==============================] - 2s 5ms/step - loss: 26.5345 - val_loss: 26.7717
# Epoch 10/20
# 515/515 [==============================] - 2s 5ms/step - loss: 26.4694 - val_loss: 26.7389
# Epoch 11/20
# 515/515 [==============================] - 3s 5ms/step - loss: 26.4369 - val_loss: 26.7196
# Epoch 12/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.3916 - val_loss: 26.6890
# Epoch 13/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.3670 - val_loss: 26.6739
# Epoch 14/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.3466 - val_loss: 26.6632
# Epoch 15/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.3679 - val_loss: 26.6346
# Epoch 16/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.3242 - val_loss: 26.6292
# Epoch 17/20
# 515/515 [==============================] - 2s 5ms/step - loss: 26.3119 - val_loss: 26.6107
# Epoch 18/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.2817 - val_loss: 26.6248
# Epoch 19/20
# 515/515 [==============================] - 2s 5ms/step - loss: 26.2907 - val_loss: 26.5856
# Epoch 20/20
# 515/515 [==============================] - 2s 4ms/step - loss: 26.2922 - val_loss: 26.5979

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss by Epoch')
plt.legend()
plt.show()

# %%
model.save('earthquacke_model.keras')

import pickle
scaler_path = 'earthquacke_scalar'

with open(scaler_path, 'wb') as file:
    pickle.dump(scaler, file)

# %%
latitude = 19
longitude = 145

current_datetime = datetime.datetime.now()

timestamp = current_datetime.timestamp()

from keras.models import load_model

model = load_model('earthquacke_model.keras')

scaler_path = 'earthquacke_scalar'
with open(scaler_path, 'rb') as file:
    scaler = pickle.load(file)

new_data = np.array([[latitude, longitude, timestamp]])

scaled_data = scaler.transform(new_data)

predictions = model.predict(scaled_data)

Depth = predictions[0][0]
Magnitude = predictions[0][1]
print("Predicted Depth: ", Depth)
print("Predicted Magnitude: ", Magnitude)
# Out:
# 1/1 [==============================] - 0s 109ms/step
# Predicted Depth:  29.688755
# Predicted Magnitude:  5.898472
